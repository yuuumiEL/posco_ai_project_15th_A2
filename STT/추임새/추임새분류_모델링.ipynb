# %% [markdown]
# # library importing

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import sklearn
import random
from unicodedata import normalize
from keras.layers import Dense
from keras import Input
from tensorflow.keras import Model
from tensorflow.keras.utils import to_categorical
from keras.layers import Dense, TimeDistributed, Dropout, Bidirectional, GRU, BatchNormalization, Activation, LeakyReLU, LSTM, Flatten, RepeatVector, Permute, Multiply, Conv2D, MaxPooling2D

# %% [markdown]
# ## 예시로 하나 해보기

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()

wav, sr = librosa.load('./dataset/train/음100.wav', sr=16000)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1183         _error_check(_snd.sf_error(file_ptr),
# -> 1184                      "Error opening {0!r}: ".format(self.name))
#    1185         if mode_int == _snd.SFM_WRITE:
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening './dataset/train/음100.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-25572a7ea509> in <module>()
#       2 scaler = preprocessing.StandardScaler()
#       3
# ----> 4 wav, sr = librosa.load('./dataset/train/음100.wav', sr=16000)
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     164         if isinstance(path, (str, pathlib.PurePath)):
#     165             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167         else:
#     168             raise (exc)
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     188
#     189     y = []
# --> 190     with audioread.audio_open(path) as input_file:
#     191         sr_native = input_file.samplerate
#     192         n_channels = input_file.channels
#
# /usr/local/lib/python3.7/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /usr/local/lib/python3.7/dist-packages/audioread/rawread.py in __init__(self, filename)
#      60     """
#      61     def __init__(self, filename):
# ---> 62         self._fh = open(filename, 'rb')
#      63
#      64         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './dataset/train/음100.wav'

# %%
# sampling rate는 1초에 몇개의 샘플을 뽑아내느냐이다.
# 소리라는 아날로그 정보를 디지털로 표현하기 위해 시간을 아주 잘게 쪼개서 기록하는데, 이 때 1초에 몇개를 기록하느냐가 sr이다.
print('sr:', sr)
print('wav shape:', wav.shape)
print('length:', wav.shape[0]/float(sr), 'secs')
# Out:
# sr: 16000
# wav shape: (3874,)
# length: 0.242125 secs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 파형보기
plt.figure(figsize=(20,12))
plt.plot(wav)

# %%
# 일반적으로 자연어 처리에서 window size는 25ms 이다. 16000x0.025 면 한 윈도우당 400개의 샘플
# hop_length는 얼마나 이동하는지를 나타냄. 보통 10ms으로 한다. 그래서 16000x0.01=160으로 160개의 샘플씩 이동
mfcc = librosa.feature.mfcc(wav, sr=16000, n_mfcc=100, n_fft=400, hop_length=160)

# 뽑아낸 벡터들을 스케일링 한다.
mfcc = scaler.fit_transform(mfcc)

# padding 하기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39fc88d749d4> in <module>()
#       1 # 일반적으로 자연어 처리에서 window size는 25ms 이다. 16000x0.025 면 한 윈도우당 400개의 샘플
#       2 # hop_length는 얼마나 이동하는지를 나타냄. 보통 10ms으로 한다. 그래서 16000x0.01=160으로 160개의 샘플씩 이동
# ----> 3 mfcc = librosa.feature.mfcc(wav, sr=16000, n_mfcc=100, n_fft=400, hop_length=160)
#       4
#       5 # 뽑아낸 벡터들을 스케일링 한다.
#
# NameError: name 'wav' is not defined

# %%
# 얜 mfcc에 대해 padding을 하겠다는 건데 의미없는 함수..
pad1d = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i-a.shape[0])))
# mfcc가 100이므로 (100, x) 가 된다. 우리가 지정한 i보다 x가 크면 i까지만 자르고 작으면 0으로 뒷 부분을 채워준다.
pad2d = lambda a, i: a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i-a.shape[1]))))

# %% [markdown]
# mfcc가 어떻게 feature vector를 뽑아내는지 궁금하면 여기를 참조하세요 ^ㅡ^
# https://blog.naver.com/PostView.nhn?isHttpsRedirect=true&blogId=sooftware&logNo=221661644808

# %%
# 0.01초씩 이동하니까 여기서는 총 116개의 window가 생성된다. 그래서 100x116의 크기이다.
mfcc.shape
# Out:
# (100, 25)

# %%
# i를 40으로 지정했다. 코드 짜신 분의 말에 의하면 모은 음성데이터의 길이 평균이 0.4-0.5초이므로 이 길이를 40(0.46초 정도)로 정했다고 한다.
# 이 파일은 40이 안되서 padding 했네
padded_mfcc = pad2d(mfcc, 40)
padded_mfcc.shape
# Out:
# (100, 40)

# %%
# '음100' 음성의 mfcc를 시각화 한 것. '음, 그, 아'에 따라 그림이 다르게 나온다!
import librosa.display
librosa.display.specshow(padded_mfcc, sr=16000, x_axis='time')

# %% [markdown]
# # Ready for Data

# %%
# 오디오 데이터 주소
DATA_DIR = '/content/drive/MyDrive/SpeakUP_ML/dataset'

# %% [markdown]
# ## 전체 파일에 대해 해보기

# %%
# train과 test의 mfcc를 담는 공간
trainset = []
testset = []

# split each set into raw data, mfcc data, and y data
# STFT 한 것, CNN 분석하기 위해 Spectogram으로 만든 것, MF한 것, mel0spectogram 한 것
train_X = []
train_mfccs = []
train_y = []

test_X = []
test_mfccs = []
test_y = []

frame_length = 0.025
frame_stride = 0.0010

# %%
# train data를 넣는다.
for filename in os.listdir(DATA_DIR + "/train/"):
    # 파일 이름이 한국어라서 오류 안생기게 인코딩 해주기 
  filename = normalize('NFC', filename)
  try:
    # wav 포맷 데이터만 사용
    if '.wav' not in filename in filename:
      continue

    #음성파일 별로 샘플링  
    wav, sr = librosa.load(DATA_DIR+ "/train/"+ filename, sr=16000)
    # 음성파일 별로 mfcc 뽑아오기
    mfcc = librosa.feature.mfcc(wav, sr=16000, n_mfcc=100, n_fft=400, hop_length=160)
    # mfcc 값 스케일링
    mfcc = scaler.fit_transform(mfcc)
    # mfcc padding
    padded_mfcc = pad2d(mfcc, 40)

    # 추임새 별로 dataset에 추가
    if filename[0] == '어':
      trainset.append((padded_mfcc, 0))
    elif filename[0] == '음':
      trainset.append((padded_mfcc, 1))
    elif filename[0] == '그':
      trainset.append((padded_mfcc, 2))
  except Exception as e:
    print(filename, e)
    raise

# 학습 데이터를 무작위로 섞는다.
random.shuffle(trainset)

# %%
# test data를 넣는다.
for filename in os.listdir(DATA_DIR + "/test/"):
  filename = normalize('NFC', filename)
  try:
    # wav 포맷 데이터만 사용
    if '.wav' not in filename in filename:
      continue
      
    wav, sr = librosa.load(DATA_DIR+ "/test/"+ filename, sr=16000)
    
    mfcc = librosa.feature.mfcc(wav, sr=16000, n_mfcc=100, n_fft=400, hop_length=160)
    mfcc = scaler.fit_transform(mfcc)
    padded_mfcc = pad2d(mfcc, 40)

    # 추임새 별로 test dataset에 추가
    if filename[0] == '어':
      testset.append((padded_mfcc, 0))
    elif filename[0] == '음':
      testset.append((padded_mfcc, 1))
    elif filename[0] == '그':
      testset.append((padded_mfcc, 2))
  except Exception as e:
    print(filename, e)
    raise

# 평가 데이터를 무작위로 섞는다.
random.shuffle(testset)

# %%
import pandas as pd
train_list=pd.DataFrame(trainset)
train_list
# Out:
#                                                       0  1
# 0     [[-9.547132, -9.4921465, -9.596308, -9.56227, ...  2
# 1     [[-9.65416, -9.44482, -9.301204, -9.039086, -8...  0
# 2     [[-9.949874, -9.949874, -9.949874, -9.949874, ...  2
# 3     [[-9.9144535, -9.904413, -9.910401, -9.919415,...  2
# 4     [[-9.025993, -8.996222, -8.983541, -8.922666, ...  2
# ...                                                 ... ..
# 2028  [[-9.774223, -9.726879, -9.71903, -9.7029915, ...  2
# 2029  [[-9.791235, -9.7730465, -9.767772, -9.658109,...  1
# 2030  [[-9.850109, -9.834792, -9.847836, -9.841268, ...  1
# 2031  [[-9.800923, -9.763546, -9.515399, -9.452161, ...  0
# 2032  [[-9.772463, -9.799962, -9.768741, -9.75705, -...  0
#
# [2033 rows x 2 columns]

# %%
train_array=np.array(trainset)
train_array.shape
# Out:
# /home/piai/anaconda3/envs/audio/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (2033, 2)

# %%
test_array=np.array(testset)
test_array.shape
# Out:
# /home/piai/anaconda3/envs/audio/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (150, 2)

# %%
# 2033개 mfcc값만
train_mfccs = [a for (a,b) in trainset]
# 답
train_y = [b for (a,b) in trainset]

# 150개 mfcc값만
test_mfccs = [a for (a,b) in testset]
# 답
test_y = [b for (a,b) in testset]

train_mfccs = np.array(train_mfccs)
train_y = to_categorical(np.array(train_y))

test_mfccs = np.array(test_mfccs)
test_y = to_categorical(np.array(test_y))

print('train_mfccs:', train_mfccs.shape)
print('train_y:', train_y.shape)

print('test_mfccs:', test_mfccs.shape)
print('test_y:', test_y.shape)
# Out:
# train_mfccs: (2033, 100, 40)
# train_y: (2033, 3)
# test_mfccs: (150, 100, 40)
# test_y: (150, 3)

# %%
# 2033는 데이터 갯수
# 100은 1개의 window당 mfcc값
# 40은 데이터 길이 통일하려고 40으로 자른것

# %% [markdown]
# # MFCC feature로 학습

# %%
# 3차원으로 만들어서 conv 2D 쓴다
train_X_ex = np.expand_dims(train_mfccs, -1)
test_X_ex = np.expand_dims(test_mfccs, -1)
print('train X shape:', train_X_ex.shape)
print('test X shape:', test_X_ex.shape)
# Out:
# train X shape: (2033, 100, 40, 1)
# test X shape: (150, 100, 40, 1)

# %%
# 첫번째 층에는 차원을 말해준다 (100,40,1)
ip = Input(shape=train_X_ex[0].shape)

# conv2D에 첫번째 parameter: 몇가지 특징을 추출할 건지
# kernel_size 이미지 파일에서는 (3,3) 오디오 파일에서는(2,2)
# padding에 'same'을 바꿔주면 100,40이 유지된다

m = Conv2D(32, kernel_size=(4,4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4,4))(m)

m = Conv2D(32*2, kernel_size=(4,4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4,4))(m)

m = Conv2D(32*3, kernel_size=(4,4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4,4))(m)

# Conv layer는 3차원, Dense layer는 1차원이기 때문에 연결이 안됨
# 그래서 Flatten 해주어야 함
m = Flatten()(m)

m = Dense(64, activation='relu')(m)

m = Dense(32, activation='relu')(m)

# 마지막 layer에는 클래스의 갯수!!
# 활성화 함수는 softmax로 확률값 내기
op = Dense(3, activation='softmax')(m)

model = Model(ip, op)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100, 40, 1)]      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 97, 37, 96)        1632
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 24, 9, 96)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20736)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                1327168
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,330,979
# Trainable params: 1,330,979
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델선언 마무리
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X_ex,
                    train_y,
                    epochs=100,
                    batch_size=32,
                    verbose=1,
                    validation_data=(test_X_ex, test_y))
# Out:
# Epoch 1/100
# 64/64 [==============================] - 4s 60ms/step - loss: 0.5919 - accuracy: 0.7506 - val_loss: 0.5274 - val_accuracy: 0.8000
# Epoch 2/100
# 64/64 [==============================] - 4s 58ms/step - loss: 0.2644 - accuracy: 0.9016 - val_loss: 0.4890 - val_accuracy: 0.8267
# Epoch 3/100
# 64/64 [==============================] - 4s 57ms/step - loss: 0.2405 - accuracy: 0.9080 - val_loss: 0.6377 - val_accuracy: 0.8333
# Epoch 4/100
# 64/64 [==============================] - 4s 57ms/step - loss: 0.1640 - accuracy: 0.9361 - val_loss: 0.8226 - val_accuracy: 0.8533
# Epoch 5/100
# 64/64 [==============================] - 4s 56ms/step - loss: 0.1419 - accuracy: 0.9493 - val_loss: 0.8214 - val_accuracy: 0.8467
# Epoch 6/100
# 64/64 [==============================] - 4s 56ms/step - loss: 0.1839 - accuracy: 0.9262 - val_loss: 0.8374 - val_accuracy: 0.8733
# Epoch 7/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.1169 - accuracy: 0.9567 - val_loss: 0.9631 - val_accuracy: 0.7800
# Epoch 8/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0860 - accuracy: 0.9680 - val_loss: 1.0721 - val_accuracy: 0.8133
# Epoch 9/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0801 - accuracy: 0.9680 - val_loss: 1.0134 - val_accuracy: 0.8400
# Epoch 10/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0580 - accuracy: 0.9779 - val_loss: 1.0944 - val_accuracy: 0.8333
# Epoch 11/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0747 - accuracy: 0.9734 - val_loss: 1.0617 - val_accuracy: 0.8267
# Epoch 12/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0570 - accuracy: 0.9764 - val_loss: 0.8859 - val_accuracy: 0.8533
# Epoch 13/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0279 - accuracy: 0.9926 - val_loss: 1.0982 - val_accuracy: 0.8333
# Epoch 14/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0209 - accuracy: 0.9956 - val_loss: 1.2786 - val_accuracy: 0.8267
# Epoch 15/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0612 - accuracy: 0.9764 - val_loss: 1.3620 - val_accuracy: 0.8600
# Epoch 16/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0426 - accuracy: 0.9877 - val_loss: 1.3318 - val_accuracy: 0.8533
# Epoch 17/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0170 - accuracy: 0.9966 - val_loss: 1.1933 - val_accuracy: 0.8400
# Epoch 18/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0101 - accuracy: 0.9980 - val_loss: 1.3353 - val_accuracy: 0.8400
# Epoch 19/100
# 64/64 [==============================] - 3s 52ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 1.2570 - val_accuracy: 0.8400
# Epoch 20/100
# 64/64 [==============================] - 3s 52ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 1.6209 - val_accuracy: 0.8400
# Epoch 21/100
# 64/64 [==============================] - 3s 52ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 1.4873 - val_accuracy: 0.8200
# Epoch 22/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 1.2916 - val_accuracy: 0.8267
# Epoch 23/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 1.5166 - val_accuracy: 0.8200
# Epoch 24/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 1.6185 - val_accuracy: 0.8200
# Epoch 25/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 1.4332 - val_accuracy: 0.8400
# Epoch 26/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 1.4701 - val_accuracy: 0.8533
# Epoch 27/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 1.5860 - val_accuracy: 0.8200
# Epoch 28/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 1.6206 - val_accuracy: 0.8200
# Epoch 29/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 1.4812 - val_accuracy: 0.8400
# Epoch 30/100
# 64/64 [==============================] - 3s 54ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 1.4621 - val_accuracy: 0.8133
# Epoch 31/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 1.5259 - val_accuracy: 0.8467
# Epoch 32/100
# 64/64 [==============================] - 3s 53ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.6942 - val_accuracy: 0.8133
# Epoch 33/100
# 64/64 [==============================] - 3s 52ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 1.5088 - val_accuracy: 0.8533
# Epoch 34/100
# 64/64 [==============================] - 3s 51ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.5637 - val_accuracy: 0.8267
# Epoch 35/100
# 64/64 [==============================] - 3s 52ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.7875 - val_accuracy: 0.8200
# Epoch 36/100
# 64/64 [==============================] - 3s 49ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 1.3889 - val_accuracy: 0.8400
# Epoch 37/100
# 64/64 [==============================] - 3s 51ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 1.5778 - val_accuracy: 0.8200
# Epoch 38/100
# 64/64 [==============================] - 3s 49ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 1.5365 - val_accuracy: 0.8400
# Epoch 39/100
# 64/64 [==============================] - 3s 50ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.5270 - val_accuracy: 0.8400
# Epoch 40/100
# 64/64 [==============================] - 3s 50ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4949 - val_accuracy: 0.8333
# Epoch 41/100
# 64/64 [==============================] - 3s 50ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 1.7096 - val_accuracy: 0.8467
# Epoch 42/100
# 64/64 [==============================] - 3s 51ms/step - loss: 8.5071e-04 - accuracy: 0.9995 - val_loss: 1.5846 - val_accuracy: 0.8467
# Epoch 43/100
# 64/64 [==============================] - 3s 48ms/step - loss: 9.4297e-04 - accuracy: 1.0000 - val_loss: 1.6425 - val_accuracy: 0.8400
# Epoch 44/100
# 64/64 [==============================] - 3s 49ms/step - loss: 7.7651e-04 - accuracy: 1.0000 - val_loss: 1.6696 - val_accuracy: 0.8533
# Epoch 45/100
# 64/64 [==============================] - 3s 50ms/step - loss: 6.6009e-04 - accuracy: 1.0000 - val_loss: 1.6303 - val_accuracy: 0.8467
# Epoch 46/100
# 64/64 [==============================] - 3s 50ms/step - loss: 7.7432e-04 - accuracy: 1.0000 - val_loss: 1.8275 - val_accuracy: 0.8467
# Epoch 47/100
# 64/64 [==============================] - 3s 49ms/step - loss: 5.3444e-04 - accuracy: 1.0000 - val_loss: 1.6316 - val_accuracy: 0.8533
# Epoch 48/100
# 64/64 [==============================] - 3s 49ms/step - loss: 4.6732e-04 - accuracy: 1.0000 - val_loss: 1.6909 - val_accuracy: 0.8400
# Epoch 49/100
# 64/64 [==============================] - 3s 50ms/step - loss: 7.0627e-04 - accuracy: 1.0000 - val_loss: 1.8185 - val_accuracy: 0.8400
# Epoch 50/100
# 64/64 [==============================] - 3s 49ms/step - loss: 0.2644 - accuracy: 0.9380 - val_loss: 0.7819 - val_accuracy: 0.8600
# Epoch 51/100
# 64/64 [==============================] - 3s 50ms/step - loss: 0.1383 - accuracy: 0.9444 - val_loss: 0.9706 - val_accuracy: 0.8467
# Epoch 52/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0577 - accuracy: 0.9774 - val_loss: 1.0944 - val_accuracy: 0.8733
# Epoch 53/100
# 64/64 [==============================] - 3s 48ms/step - loss: 0.0254 - accuracy: 0.9926 - val_loss: 1.5664 - val_accuracy: 0.8667
# Epoch 54/100
# 64/64 [==============================] - 3s 48ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 1.4959 - val_accuracy: 0.8600
# Epoch 55/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 1.5556 - val_accuracy: 0.8267
# Epoch 56/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 1.6371 - val_accuracy: 0.8667
# Epoch 57/100
# 64/64 [==============================] - 3s 48ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.7014 - val_accuracy: 0.8533
# Epoch 58/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 1.5801 - val_accuracy: 0.8600
# Epoch 59/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.7279 - val_accuracy: 0.8600
# Epoch 60/100
# 64/64 [==============================] - 3s 45ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6167 - val_accuracy: 0.8600
# Epoch 61/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7376 - val_accuracy: 0.8667
# Epoch 62/100
# 64/64 [==============================] - 3s 48ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.7682 - val_accuracy: 0.8667
# Epoch 63/100
# 64/64 [==============================] - 3s 49ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.7558 - val_accuracy: 0.8533
# Epoch 64/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.6876 - val_accuracy: 0.8600
# Epoch 65/100
# 64/64 [==============================] - 3s 49ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.7139 - val_accuracy: 0.8467
# Epoch 66/100
# 64/64 [==============================] - 3s 47ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.8051 - val_accuracy: 0.8600
# Epoch 67/100
# 64/64 [==============================] - 3s 48ms/step - loss: 8.3574e-04 - accuracy: 1.0000 - val_loss: 1.7172 - val_accuracy: 0.8600
# Epoch 68/100
# 64/64 [==============================] - 3s 48ms/step - loss: 7.6392e-04 - accuracy: 1.0000 - val_loss: 1.7540 - val_accuracy: 0.8600
# Epoch 69/100
# 64/64 [==============================] - 3s 48ms/step - loss: 7.0083e-04 - accuracy: 1.0000 - val_loss: 1.7470 - val_accuracy: 0.8533
# Epoch 70/100
# 64/64 [==============================] - 3s 47ms/step - loss: 5.8532e-04 - accuracy: 1.0000 - val_loss: 1.7620 - val_accuracy: 0.8600
# Epoch 71/100
# 64/64 [==============================] - 3s 49ms/step - loss: 8.0645e-04 - accuracy: 1.0000 - val_loss: 1.8146 - val_accuracy: 0.8600
# Epoch 72/100
# 64/64 [==============================] - 3s 49ms/step - loss: 5.4764e-04 - accuracy: 1.0000 - val_loss: 1.7952 - val_accuracy: 0.8533
# Epoch 73/100
# 64/64 [==============================] - 3s 49ms/step - loss: 4.1785e-04 - accuracy: 1.0000 - val_loss: 1.8504 - val_accuracy: 0.8667
# Epoch 74/100
# 64/64 [==============================] - 3s 48ms/step - loss: 3.9874e-04 - accuracy: 1.0000 - val_loss: 1.8039 - val_accuracy: 0.8667
# Epoch 75/100
# 64/64 [==============================] - 3s 47ms/step - loss: 3.5838e-04 - accuracy: 1.0000 - val_loss: 1.7795 - val_accuracy: 0.8600
# Epoch 76/100
# 64/64 [==============================] - 3s 48ms/step - loss: 3.3739e-04 - accuracy: 1.0000 - val_loss: 1.8278 - val_accuracy: 0.8600
# Epoch 77/100
# 64/64 [==============================] - 3s 48ms/step - loss: 3.4128e-04 - accuracy: 1.0000 - val_loss: 1.8090 - val_accuracy: 0.8533
# Epoch 78/100
# 64/64 [==============================] - 3s 49ms/step - loss: 2.7753e-04 - accuracy: 1.0000 - val_loss: 1.8236 - val_accuracy: 0.8533
# Epoch 79/100
# 64/64 [==============================] - 3s 50ms/step - loss: 2.4831e-04 - accuracy: 1.0000 - val_loss: 1.8166 - val_accuracy: 0.8533
# Epoch 80/100
# 64/64 [==============================] - 3s 48ms/step - loss: 2.4183e-04 - accuracy: 1.0000 - val_loss: 1.7949 - val_accuracy: 0.8600
# Epoch 81/100
# 64/64 [==============================] - 3s 50ms/step - loss: 2.0898e-04 - accuracy: 1.0000 - val_loss: 1.8044 - val_accuracy: 0.8600
# Epoch 82/100
# 64/64 [==============================] - 3s 49ms/step - loss: 1.9418e-04 - accuracy: 1.0000 - val_loss: 1.8227 - val_accuracy: 0.8600
# Epoch 83/100
# 64/64 [==============================] - 3s 48ms/step - loss: 1.8222e-04 - accuracy: 1.0000 - val_loss: 1.8357 - val_accuracy: 0.8600
# Epoch 84/100
# 64/64 [==============================] - 3s 47ms/step - loss: 1.7477e-04 - accuracy: 1.0000 - val_loss: 1.8029 - val_accuracy: 0.8600
# Epoch 85/100
# 64/64 [==============================] - 3s 49ms/step - loss: 1.5592e-04 - accuracy: 1.0000 - val_loss: 1.8091 - val_accuracy: 0.8600
# Epoch 86/100
# 64/64 [==============================] - 3s 49ms/step - loss: 1.5413e-04 - accuracy: 1.0000 - val_loss: 1.8298 - val_accuracy: 0.8600
# Epoch 87/100
# 64/64 [==============================] - 3s 47ms/step - loss: 1.4407e-04 - accuracy: 1.0000 - val_loss: 1.7897 - val_accuracy: 0.8600
# Epoch 88/100
# 64/64 [==============================] - 3s 47ms/step - loss: 1.3692e-04 - accuracy: 1.0000 - val_loss: 1.8270 - val_accuracy: 0.8533
# Epoch 89/100
# 64/64 [==============================] - 3s 47ms/step - loss: 1.3068e-04 - accuracy: 1.0000 - val_loss: 1.8187 - val_accuracy: 0.8600
# Epoch 90/100
# 64/64 [==============================] - 3s 48ms/step - loss: 1.1780e-04 - accuracy: 1.0000 - val_loss: 1.8347 - val_accuracy: 0.8600
# Epoch 91/100
# 64/64 [==============================] - 3s 47ms/step - loss: 1.1749e-04 - accuracy: 1.0000 - val_loss: 1.8380 - val_accuracy: 0.8600
# Epoch 92/100
# 64/64 [==============================] - 3s 49ms/step - loss: 1.0435e-04 - accuracy: 1.0000 - val_loss: 1.8066 - val_accuracy: 0.8600
# Epoch 93/100
# 64/64 [==============================] - 3s 48ms/step - loss: 9.6566e-05 - accuracy: 1.0000 - val_loss: 1.8458 - val_accuracy: 0.8533
# Epoch 94/100
# 64/64 [==============================] - 3s 47ms/step - loss: 9.3443e-05 - accuracy: 1.0000 - val_loss: 1.7931 - val_accuracy: 0.8600
# Epoch 95/100
# 64/64 [==============================] - 3s 49ms/step - loss: 9.1816e-05 - accuracy: 1.0000 - val_loss: 1.8220 - val_accuracy: 0.8600
# Epoch 96/100
# 64/64 [==============================] - 3s 48ms/step - loss: 8.4793e-05 - accuracy: 1.0000 - val_loss: 1.8263 - val_accuracy: 0.8600
# Epoch 97/100
# 64/64 [==============================] - 3s 49ms/step - loss: 8.1459e-05 - accuracy: 1.0000 - val_loss: 1.8551 - val_accuracy: 0.8600
# Epoch 98/100
# 64/64 [==============================] - 3s 47ms/step - loss: 7.7863e-05 - accuracy: 1.0000 - val_loss: 1.8546 - val_accuracy: 0.8533
# Epoch 99/100
# 64/64 [==============================] - 3s 48ms/step - loss: 7.2179e-05 - accuracy: 1.0000 - val_loss: 1.8624 - val_accuracy: 0.8533
# Epoch 100/100
# 64/64 [==============================] - 3s 49ms/step - loss: 6.7562e-05 - accuracy: 1.0000 - val_loss: 1.8476 - val_accuracy: 0.8533

# %%
model.save('./filler_classifier_0928.h5')

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ## 하나만 넣어서 테스트 해보기

# %%
wav, sr = librosa.load('./dataset/train/그603.wav', sr=16000)
mfcc = librosa.feature.mfcc(wav, sr=16000, n_mfcc=100, n_fft=400, hop_length=160)
mfcc = scaler.fit_transform(mfcc)
padded_mfcc = pad2d(mfcc, 40)

# %%
padded_mfcc = np.expand_dims(padded_mfcc, -1)

# %%
padded_mfcc = np.expand_dims(padded_mfcc, 0)

# %%
padded_mfcc.shape
# Out:
# (1, 100, 40, 1)

# %%
from keras.models import load_model

# %%
filler_classifier_model = load_model('./filler_classifier_0928.h5')

# %%
filler_classifier_model.predict(padded_mfcc)
# Out:
# array([[8.0413560e-09, 1.3782818e-10, 1.0000000e+00]], dtype=float32)

# %%
# 얘는 class 2,  '그'이다!!!!!!
